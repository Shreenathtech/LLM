# %%
print("Hi Shreenath")
# Out:
# Hi Shreenath

# %%
stark = list(range(1,10))
print (stark)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# !git add .
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git config --global user.email "shreenathsp00@gmail.com"

# %%
# !git clone https://github.com/Shreenathtech/LLM.git
# Out:
# Cloning into 'LLM'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
cd LLM
# Out:
# /content/LLM

# %%
pwd
# Out:
# '/content/LLM'

# %%
ls
